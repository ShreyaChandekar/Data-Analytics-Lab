# %% [markdown]
# <a href="https://colab.research.google.com/github/ShreyaChandekar/Data-Analytics-Lab/blob/Main/Collect_Data_from_Files.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Load data from Files

# %% [markdown]
# ### Import Pandas Library

# %%
import pandas as pd

# %% [markdown]
# ### Load the data from CSV File

# %%
# Read a CSV file
df_csv = pd.read_csv('House_Data.csv')

# %%
# First 5 Rows of Data Frame
df_csv.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
# ...

# %%
# Struture of the Data frame
df_csv.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             21613 non-null  int64
#  1   date           21613 non-null  object
#  2   price          21613 non-null  float64
#  3   bedrooms       21613 non-null  int64
#  4   bathrooms      21613 non-null  float64
#  5   sqft_living    21613 non-null  int64
#  6   sqft_lot       21613 non-null  int64
#  7   floors         21613 non-null  float64
#  8   waterfront     21613 non-null  int64
#  9   view           21613 non-null  int64
#  10  condition      21613 non-null  int64
#  11  grade          21613 non-null  int64
#  12  sqft_above     21613 non-null  int64
#  13  sqft_basement  21613 non-null  int64
#  14  yr_built       21613 non-null  int64
#  15  yr_renovated   21613 non-null  int64
#  16  zipcode        21613 non-null  int64
# ...

# %%
# Read a CSV file using header paramenters
df_csv = pd.read_csv('House_Data.csv', header=0)
df_csv.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
# ...

# %%
# Read a CSV file using header and usecols paramenters
df_csv = pd.read_csv('House_Data.csv', header=0, usecols=["id", "price", "bedrooms"])
df_csv.head()
# Out:
#            id     price  bedrooms
# 0  7129300520  221900.0         3
# 1  6414100192  538000.0         3
# 2  5631500400  180000.0         2
# 3  2487200875  604000.0         4
# 4  1954400510  510000.0         3

# %%
# Read a CSV file using header, usecols and index_col paramenters
df_csv = pd.read_csv('House_Data.csv', header=0, usecols=["id", "price", "bedrooms"], index_col=['id'])
df_csv.head()
# Out:
#                price  bedrooms
# id
# 7129300520  221900.0         3
# 6414100192  538000.0         3
# 5631500400  180000.0         2
# 2487200875  604000.0         4
# 1954400510  510000.0         3

# %%
# Read a CSV file using header, usecols, index_col and nrows paramenters
df_csv = pd.read_csv('House_Data.csv', header=0, usecols=["id", "price", "bedrooms"], index_col=['id'], nrows=10)
df_csv.head()
# Out:
#                price  bedrooms
# id
# 7129300520  221900.0         3
# 6414100192  538000.0         3
# 5631500400  180000.0         2
# 2487200875  604000.0         4
# 1954400510  510000.0         3

# %%
# Read a CSV file using header, usecols, index_col, nrows and skiprows paramenters
df_csv = pd.read_csv('House_Data.csv', header=0, usecols=["id", "price", "bedrooms"], index_col=['id'], nrows=10, skiprows=[2,4])
df_csv.head()
# Out:
#                 price  bedrooms
# id
# 7129300520   221900.0         3
# 5631500400   180000.0         2
# 1954400510   510000.0         3
# 7237550310  1225000.0         4
# 1321400060   257500.0         3

# %% [markdown]
# ### Load Data from Text file

# %%
# Read a Text file
df_txt = pd.read_csv('/content/drive/MyDrive/Data Analytics/Data Collection/Collect Data From Files/Collect Data from Files Exploration /House_Data.txt')

# %%
# First 5 Rows of Data Frame
df_txt.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
# ...

# %%
# Struture of the Data frame
df_txt.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             21613 non-null  int64
#  1   date           21613 non-null  object
#  2   price          21613 non-null  float64
#  3   bedrooms       21613 non-null  int64
#  4   bathrooms      21613 non-null  float64
#  5   sqft_living    21613 non-null  int64
#  6   sqft_lot       21613 non-null  int64
#  7   floors         21613 non-null  float64
#  8   waterfront     21613 non-null  int64
#  9   view           21613 non-null  int64
#  10  condition      21613 non-null  int64
#  11  grade          21613 non-null  int64
#  12  sqft_above     21613 non-null  int64
#  13  sqft_basement  21613 non-null  int64
#  14  yr_built       21613 non-null  int64
#  15  yr_renovated   21613 non-null  int64
#  16  zipcode        21613 non-null  int64
# ...

# %% [markdown]
# ### Load Data from Excel File

# %%
# Read a Excel file
df_xlsx = pd.read_excel('/content/drive/MyDrive/Data Analytics/Data Collection/Collect Data From Files/Collect Data from Files Exploration /House_Data.xlsx')

# %%
# First 5 Rows of Data Frame
df_xlsx.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
# ...

# %%
# Struture of the Data frame
df_xlsx.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             21613 non-null  int64
#  1   date           21613 non-null  object
#  2   price          21613 non-null  float64
#  3   bedrooms       21613 non-null  int64
#  4   bathrooms      21613 non-null  float64
#  5   sqft_living    21613 non-null  int64
#  6   sqft_lot       21613 non-null  int64
#  7   floors         21613 non-null  float64
#  8   waterfront     21613 non-null  int64
#  9   view           21613 non-null  int64
#  10  condition      21613 non-null  int64
#  11  grade          21613 non-null  int64
#  12  sqft_above     21613 non-null  int64
#  13  sqft_basement  21613 non-null  int64
#  14  yr_built       21613 non-null  int64
#  15  yr_renovated   21613 non-null  int64
#  16  zipcode        21613 non-null  int64
# ...

# %% [markdown]
# ### Load Data from JSON File

# %%
# Read a JSON file
df_json = pd.read_json('/content/drive/MyDrive/Data Analytics/Data Collection/Collect Data From Files/Collect Data from Files Exploration /House_Data.json')

# %%
# First 5 Rows of Data Frame
df_json.head()
# Out:
#            id       date   price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0  7129300520 2014-10-13  221900         3       1.00         1180      5650
# 1  6414100192 2014-12-09  538000         3       2.25         2570      7242
# 2  5631500400 2015-02-25  180000         2       1.00          770     10000
# 3  2487200875 2014-12-09  604000         4       3.00         1960      5000
# 4  1954400510 2015-02-18  510000         3       2.00         1680      8080
#
#    floors  waterfront  view  ...  grade  sqft_above  sqft_basement  yr_built  \
# 0     1.0           0     0  ...      7        1180              0      1955
# 1     2.0           0     0  ...      7        2170            400      1951
# 2     1.0           0     0  ...      6         770              0      1933
# 3     1.0           0     0  ...      7        1050            910      1965
# 4     1.0           0     0  ...      8        1680              0      1987
#
# ...

# %%
# Struture of the Data frame
df_json.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             21613 non-null  int64
#  1   date           21613 non-null  datetime64[ns]
#  2   price          21613 non-null  int64
#  3   bedrooms       21613 non-null  int64
#  4   bathrooms      21613 non-null  float64
#  5   sqft_living    21613 non-null  int64
#  6   sqft_lot       21613 non-null  int64
#  7   floors         21613 non-null  float64
#  8   waterfront     21613 non-null  int64
#  9   view           21613 non-null  int64
#  10  condition      21613 non-null  int64
#  11  grade          21613 non-null  int64
#  12  sqft_above     21613 non-null  int64
#  13  sqft_basement  21613 non-null  int64
#  14  yr_built       21613 non-null  int64
#  15  yr_renovated   21613 non-null  int64
#  16  zipcode        21613 non-null  int64
# ...

# %% [markdown]
# ### Load Data from XML File

# %%
# Read a XML file
df_xml = pd.read_xml('/content/drive/MyDrive/Data Analytics/Data Collection/Collect Data From Files/Collect Data from Files Exploration /House_Data.xml')

# %%
# First 5 Rows of Data Frame
df_xml.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
# ...

# %%
# Struture of the Data frame
df_xml.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             21613 non-null  int64
#  1   date           21613 non-null  object
#  2   price          21613 non-null  float64
#  3   bedrooms       21613 non-null  int64
#  4   bathrooms      21613 non-null  float64
#  5   sqft_living    21613 non-null  int64
#  6   sqft_lot       21613 non-null  int64
#  7   floors         21613 non-null  float64
#  8   waterfront     21613 non-null  int64
#  9   view           21613 non-null  int64
#  10  condition      21613 non-null  int64
#  11  grade          21613 non-null  int64
#  12  sqft_above     21613 non-null  int64
#  13  sqft_basement  21613 non-null  int64
#  14  yr_built       21613 non-null  int64
#  15  yr_renovated   21613 non-null  int64
#  16  zipcode        21613 non-null  int64
# ...

# %% [markdown]
# ### Load Data from HTML File

# %%
# Read a HTML file
df_html = pd.read_html('/content/drive/MyDrive/Data Analytics/Data Collection/Collect Data From Files/Collect Data from Files Exploration /House_Data.htm')[0]

# %%
# First 5 Rows of Data Frame
df_html.head()
# Out:
#            0                1       2         3          4            5   \
# 0          id             date   price  bedrooms  bathrooms  sqft_living
# 1  7129300520  20141013T000000  221900         3          1         1180
# 2  6414100192  20141209T000000  538000         3       2.25         2570
# 3  5631500400  20150225T000000  180000         2          1          770
# 4  2487200875  20141209T000000  604000         4          3         1960
#
#          6       7           8     9   ...     11          12             13  \
# 0  sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement
# 1      5650       1           0     0  ...      7        1180              0
# 2      7242       2           0     0  ...      7        2170            400
# 3     10000       1           0     0  ...      6         770              0
# 4      5000       1           0     0  ...      7        1050            910
#
# ...

# %%
# Struture of the Data frame
df_html.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21614 entries, 0 to 21613
# Data columns (total 21 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       21614 non-null  object
#  1   1       21614 non-null  object
#  2   2       21614 non-null  object
#  3   3       21614 non-null  object
#  4   4       21614 non-null  object
#  5   5       21614 non-null  object
#  6   6       21614 non-null  object
#  7   7       21614 non-null  object
#  8   8       21614 non-null  object
#  9   9       21614 non-null  object
#  10  10      21614 non-null  object
#  11  11      21614 non-null  object
#  12  12      21614 non-null  object
#  13  13      21614 non-null  object
#  14  14      21614 non-null  object
#  15  15      21614 non-null  object
#  16  16      21614 non-null  object
#  17  17      21614 non-null  object
#  18  18      21614 non-null  object
#  19  19      21614 non-null  object
#  20  20      21614 non-null  object
# ...
